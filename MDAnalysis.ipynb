# %%
import MDAnalysis
from MDAnalysis.tests.datafiles import PSF, DCD, TPR, XTC

# %%
u = MDAnalysis.Universe(TPR, XTC)

# %%
u.residues
# Out:
# <ResidueGroup with 11302 residues>

# %%
u.atoms
# Out:
# <AtomGroup with 47681 atoms>

# %%
u.residues[0].atoms
# Out:
# <AtomGroup with 19 atoms>

# %%
u.select_atoms("protein")
# Out:
# <AtomGroup with 3341 atoms>
